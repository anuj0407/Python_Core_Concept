# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot table

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df["Month"] = df["Date"].dt.month_name()
df["Quarter"] = 'Q' + df["Date"].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    937     60   John  January      Q1
# 1  2023-01-02       B   West    679     71   Mary  January      Q1
# 2  2023-01-03       C  North    769     14    Bob  January      Q1
# 3  2023-01-04       D  South    574     61  Alice  January      Q1
# 4  2023-01-05       A   East    712     25   John  January      Q1
# 5  2023-01-06       B   West    768     72   Mary  January      Q1
# 6  2023-01-07       C  North    145     97    Bob  January      Q1
# 7  2023-01-08       D  South    902     73  Alice  January      Q1
# 8  2023-01-09       A   East    130     45   John  January      Q1
# 9  2023-01-10       B   West    108     62   Mary  January      Q1
# 10 2023-01-11       C  North    194     16    Bob  January      Q1
# 11 2023-01-12       D  South    502     22  Alice  January      Q1
# 12 2023-01-13       A   East    257     77   John  January      Q1
# 13 2023-01-14       B   West    700     57   Mary  January      Q1
# 14 2023-01-15       C  North    514     89    Bob  January      Q1
# 15 2023-01-16       D  South    578     77  Alice  January      Q1
# 16 2023-01-17       A   East    639     30   John  January      Q1
# 17 2023-01-18       B   West    416     36   Mary  January      Q1
# 18 2023-01-19       C  North    786     80    Bob  January      Q1
# 19 2023-01-20       D  South    519     35  Alice  January      Q1

# %%
pivot2 = pd.pivot_table(df,values = "Sales",index = "Region",columns = "Product",aggfunc = "median")
pivot2
# Out:
# Product      A      B      C      D
# Region
# East     639.0    NaN    NaN    NaN
# North      NaN    NaN  514.0    NaN
# South      NaN    NaN    NaN  574.0
# West       NaN  679.0    NaN    NaN

# %%
pd.pivot_table(df,values = ["Sales","Units"],index = "Region",columns = "Product")
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     535.0    NaN    NaN    NaN  47.4   NaN   NaN   NaN
# North      NaN    NaN  481.6    NaN   NaN   NaN  59.2   NaN
# South      NaN    NaN    NaN  615.0   NaN   NaN   NaN  53.6
# West       NaN  534.2    NaN    NaN   NaN  59.6   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
